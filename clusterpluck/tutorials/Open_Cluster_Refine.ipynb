# %%
import clusterpluck as cp
from clusterpluck.gaia import Refine, Info, Plotting
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
cluster = cp.search_name('NGC1980', 0.3)
# Out:
# Number of stars: 421
# RA: 05 35 24 Dec: -05 54.9 Rad: 0.3
# PM_RA: 0.46 PM_Dec: -1.01 PM_Rad: 2
# Distance range: 370 pc to 5557 pc

# %%
t = Refine.load(cluster)

# %%
Refine.pm_plot(t)

# %%
cluster = cp.search('05 35 24', '-05 54.9', 0.3, 1.3, 0.5, 1.5, 250, 550)
# Out:
# Number of stars: 426
# RA: 05 35 24 Dec: -05 54.9 Rad: 0.3
# PM_RA: 1.3 PM_Dec: 0.5 PM_Rad: 1.5
# Distance range: 250 pc to 550 pc

# %%
t = Refine.load(cluster)

# %%
Refine.pm_plot(t)

# %%
Refine.map(t)

# %%
Plotting.cmd2(t)

# %%
Refine.d_plot(t)

# %%
Info.dist(t)
# Out:
# Distance: 382 pc
# 5%: 331 pc - 95%: 436
