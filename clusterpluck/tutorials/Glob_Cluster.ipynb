# %%
import clusterpluck as cp
from clusterpluck.gaia import Refine, Info, Plotting
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
cluster = cp.search_name('M5', 0.4)
# Out:
# Number of stars: 4559
# RA: 15 18 33.22 Dec: +02 04 51.7 Rad: 0.4
# PM_RA: 4.06 PM_Dec: -9.89 PM_Rad: 2
# Distance range: 271 pc to 4066 pc

# %%
t = Refine.load(cluster)

# %%
Refine.pm_plot(t)

# %%
Refine.map(t)

# %%
Plotting.cmd2(t)

# %%
cluster = cp.search('15 18 33.22', '+02 04 51.7', 0.4, 4.06, -9.89, 3, 1, 100000)
# Out:
# Number of stars: 9119
# RA: 15 18 33.22 Dec: +02 04 51.7 Rad: 0.4
# PM_RA: 4.06 PM_Dec: -9.89 PM_Rad: 3
# Distance range: 1 pc to 100000 pc

# %%
t = Refine.load(cluster)

# %%
Refine.pm_plot(t)

# %%
Refine.map(t)

# %%
Plotting.cmd2(t)
