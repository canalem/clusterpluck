# %%
import clusterpluck as cp
from clusterpluck.gaia import Refine, Info, Plotting
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
cluster = cp.search_name('M45', 2, 10, 3)
# Out:
# Number of stars: 1095
# RA: 03 47 00 Dec: +24 07.0 Rad: 2
# PM_RA: 19.997 PM_Dec: -45.548 PM_Rad: 10
# Distance range: 68 pc to 204 pc

# %%
t = Refine.load(cluster)

# %%
Refine.pm_plot(t)

# %%
Refine.map(t)

# %%
Plotting.cmd2(t)

# %%
Refine.d_plot(t)

# %%
Info.dist(t)
# Out:
# Distance: 135 pc
# 5%: 124 pc - 95%: 147

# %%
t
# Out:
#        parallax  parallax_error       pmra  pmra_error      pmdec  \
# 0      8.147448        0.958182  19.078968    0.613487 -46.193245
# 1      8.374685        0.877265  20.541505    0.441163 -46.081450
# 2      7.700310        0.620847  19.515752    0.451268 -45.527310
# 3      7.096029        0.572415  13.075220    0.317128 -48.403790
# 4      9.573445        0.806083  16.291673    0.404197 -47.206094
# ...         ...             ...        ...         ...        ...
# 1090  10.792423        1.897590  18.462661    1.341102 -46.896450
# 1091   5.557659        1.968000  18.434628    1.492395 -45.085031
# 1092   8.946100        3.523091  19.439553    1.709819 -47.974347
# 1093   8.039791        2.360105  19.892623    1.967774 -46.170769
# 1094   7.606743        3.402910  21.681042    2.695428 -43.254335
#
#       pmdec_error     bp_rp  phot_g_mean_mag         ra        dec  \
# 0        0.340653 -0.036376         3.615795  57.290689  24.053212
# 1        0.308180 -0.087962         3.698209  56.219005  24.113133
# 2        0.276330 -0.013768         3.863349  56.456796  24.367541
# 3        0.194580 -0.011191         4.172742  56.581671  23.948144
# 4        0.287565 -0.107325         4.261022  56.302163  24.467064
# ...           ...       ...              ...        ...        ...
# 1090     0.924697  3.265966        20.496994  55.148020  23.218543
# 1091     0.828039  2.477461        20.522566  57.856623  23.755762
# 1092     1.552777  2.312395        20.570002  57.391574  22.276519
# 1093     1.239371  2.455362        20.620213  56.800476  24.475361
# 1094     1.485062  1.899370        20.696362  56.824750  24.375293
#
#         distance  distance_error  m_v_tycho       b_v
# 0     122.737813       12.915658   3.632115 -0.093749
# 1     119.407474       11.322156   3.712627 -0.129690
# 2     129.864902        9.689303   3.880901 -0.077981
# 3     140.923894       10.519331   4.190450 -0.076183
# 4     104.455605        8.112114   4.275056 -0.143167
# ...          ...             ...        ...       ...
# 1090   92.657603       13.855473  22.482860  2.263938
# 1091  179.931880       47.053154  21.817150  1.698597
# 1092  111.780558       31.582891  21.729449  1.579846
# 1093  124.381343       28.226537  21.896458  1.682703
# 1094  131.462301       40.632919  21.539234  1.282628
#
# [1095 rows x 14 columns]
